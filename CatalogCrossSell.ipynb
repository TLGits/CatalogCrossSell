# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, fpgrowth
from mlxtend.frequent_patterns import association_rules

# %%
data = pd.read_excel('CatalogCrossSell.xls')
# data = data.set_index('Customer Number')
data.drop(columns = 'Customer Number', inplace = True)

# %%
data
# Out:
#       Clothing Division  Housewares Division  Health Products Division  \
# 0                     0                    1                         1
# 1                     0                    1                         1
# 2                     0                    1                         1
# 3                     0                    0                         1
# 4                     0                    0                         1
# ...                 ...                  ...                       ...
# 4993                  0                    0                         1
# 4994                  0                    1                         1
# 4995                  0                    0                         1
# 4996                  0                    0                         1
# 4997                  0                    0                         1
#
#       Automotive Division  Personal Electronics Division  Computers Division  \
# ...

# %%
apr_result = apriori(data, min_support = 0.1, use_colnames = True)

# %%
fpg_result = fpgrowth(data, min_support = 0.1, use_colnames = True)

# %%
apr_result
# Out:
#      support                                           itemsets
# 0   0.393557                              (Housewares Division)
# 1   1.000000                         (Health Products Division)
# 2   0.134854                              (Automotive Division)
# 3   0.467387                    (Personal Electronics Division)
# 4   0.272109                                  (Garden Division)
# 5   0.227491                            (Novelty Gift Division)
# 6   0.356943                                 (Jewelry Division)
# 7   0.393557    (Health Products Division, Housewares Division)
# 8   0.235494  (Housewares Division, Personal Electronics Div...
# 9   0.132853             (Housewares Division, Garden Division)
# 10  0.134854       (Housewares Division, Novelty Gift Division)
# 11  0.194878            (Housewares Division, Jewelry Division)
# 12  0.134854    (Health Products Division, Automotive Division)
# 13  0.467387  (Health Products Division, Personal Electronic...
# ...

# %%
fpg_result
# Out:
#      support                                           itemsets
# 0   1.000000                         (Health Products Division)
# 1   0.467387                    (Personal Electronics Division)
# 2   0.393557                              (Housewares Division)
# 3   0.227491                            (Novelty Gift Division)
# 4   0.134854                              (Automotive Division)
# 5   0.356943                                 (Jewelry Division)
# 6   0.272109                                  (Garden Division)
# 7   0.467387  (Health Products Division, Personal Electronic...
# 8   0.393557    (Health Products Division, Housewares Division)
# 9   0.235494  (Housewares Division, Personal Electronics Div...
# 10  0.235494  (Health Products Division, Housewares Division...
# 11  0.227491  (Health Products Division, Novelty Gift Division)
# 12  0.169068  (Novelty Gift Division, Personal Electronics D...
# 13  0.134854       (Housewares Division, Novelty Gift Division)
# ...

# %%
apr_con_asso = association_rules(apr_result, metric="confidence", min_threshold=0.7)
apr_con_asso
# Out:
#                                           antecedents  \
# 0                               (Housewares Division)
# 1                               (Automotive Division)
# 2                     (Personal Electronics Division)
# 3                                   (Garden Division)
# 4                             (Novelty Gift Division)
# 5                                  (Jewelry Division)
# 6                             (Novelty Gift Division)
# 7   (Housewares Division, Personal Electronics Div...
# 8              (Housewares Division, Garden Division)
# 9        (Housewares Division, Novelty Gift Division)
# 10            (Housewares Division, Jewelry Division)
# 11       (Housewares Division, Novelty Gift Division)
# 12   (Personal Electronics Division, Garden Division)
# 13  (Health Products Division, Novelty Gift Division)
# 14  (Personal Electronics Division, Novelty Gift D...
# 15                            (Novelty Gift Division)
# ...

# %%
fpg_con_asso = association_rules(fpg_result, metric="confidence", min_threshold=0.7)
fpg_con_asso
# Out:
#                                           antecedents  \
# 0                     (Personal Electronics Division)
# 1                               (Housewares Division)
# 2   (Housewares Division, Personal Electronics Div...
# 3                             (Novelty Gift Division)
# 4                             (Novelty Gift Division)
# 5   (Health Products Division, Novelty Gift Division)
# 6   (Personal Electronics Division, Novelty Gift D...
# 7                             (Novelty Gift Division)
# 8        (Housewares Division, Novelty Gift Division)
# 9        (Housewares Division, Novelty Gift Division)
# 10  (Health Products Division, Housewares Division...
# 11  (Novelty Gift Division, Housewares Division, P...
# 12       (Housewares Division, Novelty Gift Division)
# 13           (Novelty Gift Division, Garden Division)
# 14          (Novelty Gift Division, Jewelry Division)
# 15                              (Automotive Division)
# ...

# %%
apr_lift_asso = association_rules(apr_result, metric="lift", min_threshold=1.4)
apr_lift_asso
# Out:
#                                           antecedents  \
# 0                               (Housewares Division)
# 1                             (Novelty Gift Division)
# 2                             (Novelty Gift Division)
# 3                     (Personal Electronics Division)
# 4                             (Novelty Gift Division)
# 5                                   (Garden Division)
# 6     (Health Products Division, Housewares Division)
# 7   (Health Products Division, Novelty Gift Division)
# 8                               (Housewares Division)
# 9                             (Novelty Gift Division)
# 10       (Housewares Division, Novelty Gift Division)
# 11  (Personal Electronics Division, Novelty Gift D...
# 12  (Housewares Division, Personal Electronics Div...
# 13                            (Novelty Gift Division)
# 14                              (Housewares Division)
# 15                    (Personal Electronics Division)
# ...

# %%
fpg_lift_asso = association_rules(fpg_result, metric="lift", min_threshold=1.4)
fpg_lift_asso
# Out:
#                                           antecedents  \
# 0                             (Novelty Gift Division)
# 1                     (Personal Electronics Division)
# 2                               (Housewares Division)
# 3                             (Novelty Gift Division)
# 4                             (Novelty Gift Division)
# 5                                   (Garden Division)
# 6   (Health Products Division, Novelty Gift Division)
# 7   (Health Products Division, Personal Electronic...
# 8                             (Novelty Gift Division)
# 9                     (Personal Electronics Division)
# 10    (Health Products Division, Housewares Division)
# 11  (Health Products Division, Novelty Gift Division)
# 12                              (Housewares Division)
# 13                            (Novelty Gift Division)
# 14       (Housewares Division, Novelty Gift Division)
# 15  (Personal Electronics Division, Novelty Gift D...
# ...

# %%
apr_result.to_csv('apr_result.csv')

# %%
apr_con_asso.to_csv('apr_con_asso.csv')

# %%
apr_lift_asso.to_csv('apr_lift_asso.csv')

# %%
fpg_result.to_csv('fpg_result.csv')

# %%
fpg_con_asso.to_csv('fpg_con_asso.csv')

# %%
fpg_lift_asso.to_csv('fpg_lift_asso.csv')
